# %% [markdown]
# <a href="https://colab.research.google.com/github/valedalama/valedalama.github.io/blob/master/farmOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparing for farmOS migration from v1.x to v2
# a Jupyter Lab Notebook, prepared & hosted in Google Collaboratory, to document the process, results, next steps...

# %% [markdown]
# ## Goals of this document
# Two aspects of this migration are addressed here:
# * Validating integrity of migrated data (v1.x -> v2) of farmOS;
# * Testing the farmOS API of v2, using farmOS.py library as interface
#
# Those two issues can proceed in parallel -the sooner the better- so this analysis.  Other issues that must be addressed, but only when preconditions are met, are:
# * WFS module (for serving geospatial data): awaits the next iteration of our v2 test instance (which awaits completion of the data migration test).
# * Crop Planning module: not until some time after v2 is in production. Until then: we continue managing that data in spreadsheets.

# %% [markdown]
# ## Context
# https://farmos.discourse.group/t/farmos-2-x-releases-and-what-to-expect/736 <p>[link text](https://)
# https://farmos.discourse.group/t/looking-for-farmos-2-x-migration-testers/575/8

# %% [markdown]
# ## Validating Data Integrity, Step 1: working with CSVs

# %%
# import the software tools we're gonna need, and get version info (for reproducibility)
import pandas as pd
print("Pandas version ",pd.__version__)
# Out:
# Pandas version  1.3.0

# %% [markdown]
# ### Compare CSV output of report: all Assets of type Plant(ing, in v2.x)

# %%
# load the full table of assets/ plantings (unfiltered) from v1.x, as of Wednesday, 21 July 2021 at 09:17
df=pd.read_csv("./farm_plantings-field_farm_move_to_tid_All-field_farm_group_target_id_All-2021-07-21T09-17-26.csv")
# do hi-level overview
print("Number of Rows, Columns = ",df.shape)  #to know the depth & scope of dataframe
print("Column Headers: ",df.columns)  # to see names of column headers
print("Datatype of index = ",type(df.index[0]))  # to confirm datatype of the index
# NB: number of rows (148) is correct; matches the report in UI
# Out:
# Number of Rows, Columns =  (148, 11)
# Column Headers:  Index(['Farm asset', 'Asset ID', 'Unnamed: 2', 'Name', 'Crop/variety',
#        'Season', 'Description', 'Flags', 'Group', 'Location', 'Archived'],
#       dtype='object')
# Datatype of index =  <class 'int'>

# %% [markdown]
# Compare "Column Headers" above with those displayed in farmOS UI:
# *Asset ID*.*Name*,Crop/variety,Season,**Description**,Flags,Group,Location,**Archived**

# %%
#@title
# load the full table of assets/ plantings (unfiltered) from v2, as of Wednesday, 21 July 2021 at 09:22
df=pd.read_csv("./assets2.csv")
# do hi-level overview
print("Number of Rows, Columns = ",df.shape)  #to know the depth & scope of dataframe
print("Column Headers: ",df.columns)  # to see names of column headers
print("Datatype of index = ",type(df.index[0]))  # to confirm datatype of the index
# NB: number of rows (197) is INCORRECT, according to report in UI (just 145 records)
# Out:
# Number of Rows, Columns =  (197, 10)
# Column Headers:  Index(['Bulk update', 'image_target_id', 'ID', 'Asset name', 'Asset type',
#        'Flags', 'Parents', 'Group', 'Location', 'Status'],
#       dtype='object')
# Datatype of index =  <class 'int'>

# %% [markdown]
# Compare "Column Headers" above with those displayed in farmOS UI:
# *ID*,*Asset name*,Crop/variety,Season,Flags,**Parents**,Group,Location,**Status**

# %% [markdown]
# **Note**: there are some obvious discrepancies here, as explored in [this Discourse thread](https://farmos.discourse.group/t/looking-for-farmos-2-x-migration-testers/575/8?u=walt), including most notably the row count (which should be the same in both v1.x and v2) and column names. The row count discrepancy is a bug that developer Mike Stenta has [flagged as such](https://www.drupal.org/project/farm/issues/3224663).  As to column name discrepancies: given the scope of this upgrade, significant change to db schema were anticipated as a given, so that difference of 49 in the row count is no surprise.  What is more surprising is the difference in schema of same instance(s), comparing CSV output to view of the report as prepared in UI. Moreover, there are columns in the databaae that are filtered out of both views, though potentially important to the user, such as dates of record creation / modification, and username associated with those editing events.

# %% [markdown]
# ### Compare CSV output of subset report: Plant(ings) in Location: EiraField orchard

# %%
# load the .csv datafile from the v1.x instance, as of: Tuesday, 20 July 2021 at 19:36
df=pd.read_csv("./farm_plantings-name_EiraField-field_farm_move_to_tid_All-field_farm_group_target_id_All-2021-07-20T19-36-08.csv")
# do hi-level overview
print("Number of Rows, Columns = ",df.shape)  #to know the depth & scope of dataframe
print("Column Headers: ",df.columns)  # to see names of column headers
print("Datatype of index = ",type(df.index[0]))  # to confirm datatype of the index
# Out:
# Number of Rows, Columns =  (51, 11)
# Column Headers:  Index(['Farm asset', 'Asset ID', 'Unnamed: 2', 'Name', 'Crop/variety',
#        'Season', 'Description', 'Flags', 'Group', 'Location', 'Archived'],
#       dtype='object')
# Datatype of index =  <class 'int'>

# %%
df.tail()  # eyeball the last 5 records
# Out:
#     Farm asset  Asset ID  Unnamed: 2                              Name  \
# 46         NaN        68         NaN  2020 EiraField Plums AutumnGiant
# 47         NaN        70         NaN    2020 EiraField Plums BlackGold
# 48         NaN        69         NaN    2020 EiraField Plums BlackStar
# 49         NaN        53         NaN     2020 EiraField Plums Metheley
# 50         NaN        50         NaN      2020 EiraField Plums SãoBras
#
#          Crop/variety  Season Description  Flags  Group Location  Archived
# 46  Plums AutumnGiant    2020         NaN    NaN    NaN      NaN       NaN
# 47    Plums BlackGold    2020         NaN    NaN    NaN      NaN       NaN
# 48    Plums BlackStar    2020         NaN    NaN    NaN      NaN       NaN
# 49     Plums Metheley    2020         NaN    NaN    NaN      NaN       NaN
# 50      Plums SãoBras    2020         NaN    NaN    NaN      NaN       NaN

# %%
df.head()  #eyball the first 5 records
# Out:
#    Farm asset  Asset ID  Unnamed: 2                                  Name  \
# 0         NaN        23         NaN           2019  EiraField Apples Anna
# 1         NaN        24         NaN     2019 EiraField Apples  Jersey Mac
# 2         NaN        27         NaN            2019 EiraField Apples Fuji
# 3         NaN        25         NaN  2019 EiraField Apples Golden Dorsett
# 4         NaN        29         NaN    2019 EiraField Apples Granny Smith
#
#             Crop/variety  Season  \
# 0            Apples Anna    2019
# 1     Apples  Jersey Mac    2019
# 2            Apples Fuji    2019
# 3  Apples Golden Dorsett    2019
# 4    Apples Granny Smith    2019
#
#                                          Description  Flags  Group   Location  \
# 0  15 Trees planted in bed #1, from north end on ...    NaN    NaN  EiraField
# 1        Planted 2 at S. end of Bed #2 on 2019.02.21    NaN    NaN  EiraField
# 2                                                NaN    NaN    NaN  EiraField
# 3                                                NaN    NaN    NaN  EiraField
# 4                                                NaN    NaN    NaN  EiraField
#
#    Archived
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# load  #the .csv datafile from v2 instance, as of: Tuesday, 20 July 2021 at 17:04
df=pd.read_csv("./assets.csv")
# do hi-level overview
print("Number of Rows, Columns = ",df.shape)  #to know the depth & scope of dataframe
print("Column Headers: ",df.columns)  # to see names of column headers
print("Datatype of index = ",type(df.index[0]))  # to confirm datatype of the index
# Out:
# Number of Rows, Columns =  (52, 10)
# Column Headers:  Index(['Bulk update', 'image_target_id', 'ID', 'Asset name', 'Asset type',
#        'Flags', 'Parents', 'Group', 'Location', 'Status'],
#       dtype='object')
# Datatype of index =  <class 'int'>

# %%
df.tail()   # eyeball the last 5 records
# Out:
#     Bulk update  image_target_id  ID                       Asset name  \
# 47          NaN              NaN  72  2020 EiraField Apricots Mogador
# 48          NaN              NaN  73  2020 EiraField Apricots Mogador
# 49          NaN              NaN  74  2020 EiraField Apricots Mogador
# 50          NaN              NaN  75  2020 EiraField Apricots Mogador
# 51          NaN              NaN  76     2020 EiraField Apricots TBD?
#
#    Asset type  Flags Parents  Group Location  Status
# 47      Plant    NaN     NaN    NaN      NaN  Active
# 48      Plant    NaN     NaN    NaN      NaN  Active
# 49      Plant    NaN     NaN    NaN      NaN  Active
# 50      Plant    NaN     NaN    NaN      NaN  Active
# 51      Plant    NaN     NaN    NaN      NaN  Active

# %%
df.head()  #eyball the first 5 records
# Out:
#    Bulk update  image_target_id   ID  \
# 0          NaN              NaN  187
# 1          NaN              NaN   23
# 2          NaN              NaN   24
# 3          NaN              NaN   25
# 4          NaN              NaN   26
#
#                                  Asset name Asset type  Flags Parents  Group  \
# 0                                 EiraField       Land    NaN     18U    NaN
# 1               2019  EiraField Apples Anna      Plant    NaN     NaN    NaN
# 2         2019 EiraField Apples  Jersey Mac      Plant    NaN     NaN    NaN
# 3      2019 EiraField Apples Golden Dorsett      Plant    NaN     NaN    NaN
# 4  2019 EiraField Apples Royal Gala Riscada      Plant    NaN     NaN    NaN
#
#     Location  Status
# 0        NaN  Active
# 1  EiraField  Active
# 2  EiraField  Active
# 3  EiraField  Active
# 4  EiraField  Active

# %% [markdown]
# ## Testing the API

# %% [markdown]
# Easiest way to get a quick view of API endpoints is via [this JSON in the browser](https://vdl.farmos.dev/api/) -Firefox, that is (am unable to get human-readable view in Chrome or Safari).  From there, you can get a link to your desired endpoint... But navigating that tree to dig out what you want is not so easy.
#
# Easier, if you have some facility with Python language (built into this notebook, as it happens) would be [this farmOS.py library](https://github.com/farmOS/farmOS.py) from Paul Weidner; that's what we'll be using in this section.

# %%
from farmOS import farmOS #load the library
farm_client = farmOS(hostname="https://vdl.farmos.dev", client_id="farm", scope="farm_manager", version=2) #login
current_token = farm_client.authorize(username="apiTest", password="api+35+erAPI") #get OAuth token
farm_client.info() #poll API for endpoints
# Out:
# {'jsonapi': {'version': '1.0',
#   'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}},
#  'data': [],
#  'meta': {'links': {'me': {'meta': {'id': '65d791fe-8e35-488b-a262-e63ede764c49'},
#     'href': 'http://vdl.farmos.dev/api/user/user/65d791fe-8e35-488b-a262-e63ede764c49'}},
#   'farm': {'name': 'Quinta Vale da Lama',
#    'url': 'http://vdl.farmos.dev',
#    'version': '2.x',
#    'system_of_measurement': 'metric'}},
#  'links': {'asset--animal': {'href': 'http://vdl.farmos.dev/api/asset/animal'},
#   'asset--equipment': {'href': 'http://vdl.farmos.dev/api/asset/equipment'},
#   'asset--group': {'href': 'http://vdl.farmos.dev/api/asset/group'},
#   'asset--land': {'href': 'http://vdl.farmos.dev/api/asset/land'},
#   'asset--plant': {'href': 'http://vdl.farmos.dev/api/asset/plant'},
#   'asset--sensor': {'href': 'http://vdl.farmos.dev/api/asset/sensor'},
#   'asset--structure': {'href': 'http://vdl.farmos.dev/api/asset/structure'},
#   'asset_type--asset_type': {'href': 'http://vdl.farmos.dev/api/asset_type/asset_type'},
#   'data_stream--basic': {'href': 'http://vdl.farmos.dev/api/data_stream/basic'},
#   'data_stream--legacy_listener': {'href': 'http://vdl.farmos.dev/api/data_stream/legacy_listener'},
#   'data_stream_type--data_stream_type': {'href': 'http://vdl.farmos.dev/api/data_stream_type/data_stream_type'},
#   'entity_browser--entity_browser': {'href': 'http://vdl.farmos.dev/api/entity_browser/entity_browser'},
#   'file--file': {'href': 'http://vdl.farmos.dev/api/file/file'},
#   'flag--flag': {'href': 'http://vdl.farmos.dev/api/flag/flag'},
#   'land_type--land_type': {'href': 'http://vdl.farmos.dev/api/land_type/land_type'},
#   'layer_style--layer_style': {'href': 'http://vdl.farmos.dev/api/layer_style/layer_style'},
#   'log--activity': {'href': 'http://vdl.farmos.dev/api/log/activity'},
#   'log--birth': {'href': 'http://vdl.farmos.dev/api/log/birth'},
#   'log--harvest': {'href': 'http://vdl.farmos.dev/api/log/harvest'},
#   'log--input': {'href': 'http://vdl.farmos.dev/api/log/input'},
#   'log--maintenance': {'href': 'http://vdl.farmos.dev/api/log/maintenance'},
#   'log--observation': {'href': 'http://vdl.farmos.dev/api/log/observation'},
#   'log--seeding': {'href': 'http://vdl.farmos.dev/api/log/seeding'},
#   'log--transplanting': {'href': 'http://vdl.farmos.dev/api/log/transplanting'},
#   'log_type--log_type': {'href': 'http://vdl.farmos.dev/api/log_type/log_type'},
#   'map_behavior--map_behavior': {'href': 'http://vdl.farmos.dev/api/map_behavior/map_behavior'},
#   'map_type--map_type': {'href': 'http://vdl.farmos.dev/api/map_type/map_type'},
#   'quantity--standard': {'href': 'http://vdl.farmos.dev/api/quantity/standard'},
#   'quantity_type--quantity_type': {'href': 'http://vdl.farmos.dev/api/quantity_type/quantity_type'},
#   'self': {'href': 'http://vdl.farmos.dev/api'},
#   'structure_type--structure_type': {'href': 'http://vdl.farmos.dev/api/structure_type/structure_type'},
#   'tag_type--tag_type': {'href': 'http://vdl.farmos.dev/api/tag_type/tag_type'},
#   'taxonomy_term--animal_type': {'href': 'http://vdl.farmos.dev/api/taxonomy_term/animal_type'},
#   'taxonomy_term--crop_family': {'href': 'http://vdl.farmos.dev/api/taxonomy_term/crop_family'},
#   'taxonomy_term--log_category': {'href': 'http://vdl.farmos.dev/api/taxonomy_term/log_category'},
#   'taxonomy_term--material': {'href': 'http://vdl.farmos.dev/api/taxonomy_term/material'},
#   'taxonomy_term--plant_type': {'href': 'http://vdl.farmos.dev/api/taxonomy_term/plant_type'},
#   'taxonomy_term--season': {'href': 'http://vdl.farmos.dev/api/taxonomy_term/season'},
#   'taxonomy_term--unit': {'href': 'http://vdl.farmos.dev/api/taxonomy_term/unit'},
#   'taxonomy_vocabulary--taxonomy_vocabulary': {'href': 'http://vdl.farmos.dev/api/taxonomy_vocabulary/taxonomy_vocabulary'},
#   'user--user': {'href': 'http://vdl.farmos.dev/api/user/user'},
#   'user_role--user_role': {'href': 'http://vdl.farmos.dev/api/user_role/user_role'}}}

# %%
# logs = list(farm_client.log.iterate('observation'))
observation = farm_client.log.get('observation')
observation
# Out:
# {'jsonapi': {'version': '1.0',
#   'meta': {'links': {'self': {'href': 'http://jsonapi.org/format/1.0/'}}}},
#  'data': [{'type': 'log--observation',
#    'id': '8939bf06-844d-4f73-b649-cbe92b732fcc',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc'}},
#    'attributes': {'drupal_internal__id': 1,
#     'drupal_internal__revision_id': 70,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': '5/9/2019 - 3:55:18 PM',
#     'timestamp': '2019-05-06T23:00:00+00:00',
#     'status': 'done',
#     'created': '2019-05-09T14:58:46+00:00',
#     'changed': '2019-05-09T14:58:46+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': {'value': 'Sheep jumped their South Slope paddock ',
#      'format': 'default',
#      'processed': '<p>Sheep jumped their South Slope paddock</p>\n'},
#     'is_group_assignment': False,
#     'geometry': None,
#     'is_movement': False},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': '9d1dc5d2-cce1-4b52-8a94-007c1b772936'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/uid'}}},
#     'asset': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/file'}}},
#     'image': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': '9d1dc5d2-cce1-4b52-8a94-007c1b772936'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/quantity'}}},
#     'group': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/group'}}},
#     'location': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8939bf06-844d-4f73-b649-cbe92b732fcc/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': 'bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4'}},
#    'attributes': {'drupal_internal__id': 19,
#     'drupal_internal__revision_id': 71,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': 'Group DF Tra tor into Vehicles',
#     'timestamp': '2019-05-12T15:30:16+00:00',
#     'status': 'done',
#     'created': '2019-05-12T15:30:16+00:00',
#     'changed': '2019-05-12T15:30:16+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': None,
#     'is_group_assignment': True,
#     'geometry': None,
#     'is_movement': False},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': '9d1dc5d2-cce1-4b52-8a94-007c1b772936'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/uid'}}},
#     'asset': {'data': [{'type': 'asset--equipment',
#        'id': 'e67cbc83-09cd-4810-84dd-9e9e1ba1cd23'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/file'}}},
#     'image': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': '9d1dc5d2-cce1-4b52-8a94-007c1b772936'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/quantity'}}},
#     'group': {'data': [{'type': 'asset--group',
#        'id': '0132441e-ea1e-4071-869f-262d1dc4eb32'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/group'}}},
#     'location': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/bd5edfd9-8e8a-4fcf-8caa-7d25287bf6a4/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': '14df7753-36b5-43e5-957f-6e7cc3acef88',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88'}},
#    'attributes': {'drupal_internal__id': 20,
#     'drupal_internal__revision_id': 72,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': 'Group DumpTrailer into Vehicles',
#     'timestamp': '2019-05-12T15:33:45+00:00',
#     'status': 'done',
#     'created': '2019-05-12T15:33:45+00:00',
#     'changed': '2019-05-12T15:33:45+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': None,
#     'is_group_assignment': True,
#     'geometry': None,
#     'is_movement': False},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': '9d1dc5d2-cce1-4b52-8a94-007c1b772936'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/uid'}}},
#     'asset': {'data': [{'type': 'asset--equipment',
#        'id': '452a9679-8d79-45f8-a13e-e89c488c343c'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/file'}}},
#     'image': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': '9d1dc5d2-cce1-4b52-8a94-007c1b772936'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/quantity'}}},
#     'group': {'data': [{'type': 'asset--group',
#        'id': '0132441e-ea1e-4071-869f-262d1dc4eb32'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/group'}}},
#     'location': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/14df7753-36b5-43e5-957f-6e7cc3acef88/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': '0b3bf391-d08f-4f2c-8f8d-35238b209295',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295'}},
#    'attributes': {'drupal_internal__id': 24,
#     'drupal_internal__revision_id': 73,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': 'tomato bush located in bed N° 13',
#     'timestamp': '2019-07-11T19:04:58+00:00',
#     'status': 'done',
#     'created': '2019-07-11T19:04:58+00:00',
#     'changed': '2019-07-11T19:04:58+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': None,
#     'is_group_assignment': False,
#     'geometry': {'value': 'LINESTRING (-8.629179708659647 37.14105142926124, -8.629161603748797 37.14105730911037, -8.62939730286598 37.14156185192084, -8.629434853792189 37.14155329946989, -8.62918809056282 37.14105084128119)',
#      'geo_type': 'LineString',
#      'lat': 37.1413099967427,
#      'lon': -8.629297435008475,
#      'left': -8.629434853792189,
#      'top': 37.14156185192084,
#      'right': -8.629161603748797,
#      'bottom': 37.14105084128119,
#      'geohash': 'ey9g79k',
#      'latlon': '37.141309996743,-8.6292974350085'},
#     'is_movement': True},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': '96dcf1ac-d144-43e7-add0-56876800b8f4'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/uid'}}},
#     'asset': {'data': [{'type': 'asset--plant',
#        'id': 'cb246c0a-679b-45b3-a9fb-613e6d77dc21'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/file'}}},
#     'image': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': '96dcf1ac-d144-43e7-add0-56876800b8f4'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/quantity'}}},
#     'group': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/group'}}},
#     'location': {'data': [{'type': 'asset--land',
#        'id': '599d10f2-c6aa-4af6-a1a4-63d70e355202'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/0b3bf391-d08f-4f2c-8f8d-35238b209295/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': '283ed562-d369-4f1a-9b5e-369220f46383',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383'}},
#    'attributes': {'drupal_internal__id': 28,
#     'drupal_internal__revision_id': 74,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': 'Winter Garlic located in bed N° 7',
#     'timestamp': '2019-07-11T22:28:54+00:00',
#     'status': 'done',
#     'created': '2019-07-11T22:28:54+00:00',
#     'changed': '2019-07-11T22:28:54+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': None,
#     'is_group_assignment': False,
#     'geometry': {'value': 'MULTILINESTRING ((-8.629338964819908 37.14115863843786, -8.629336282610893 37.14115650031381), (-8.629326894879341 37.14116398374767, -8.629509955644608 37.14153434152922, -8.629475086927414 37.14154075586912, -8.629228994250298 37.14104745590782, -8.629258498549461 37.14103676527132, -8.629326894879341 37.14116612187151))',
#      'geo_type': 'MultiLineString',
#      'lat': 37.14128971028798,
#      'lon': -8.629369207975625,
#      'left': -8.629509955644608,
#      'top': 37.14154075586912,
#      'right': -8.629228994250298,
#      'bottom': 37.14103676527132,
#      'geohash': 'ey9g79k',
#      'latlon': '37.141289710288,-8.6293692079756'},
#     'is_movement': True},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': '96dcf1ac-d144-43e7-add0-56876800b8f4'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/uid'}}},
#     'asset': {'data': [{'type': 'asset--plant',
#        'id': '73ec412a-0cf3-479f-b347-8efac721bcf8'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/file'}}},
#     'image': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': '96dcf1ac-d144-43e7-add0-56876800b8f4'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/quantity'}}},
#     'group': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/group'}}},
#     'location': {'data': [{'type': 'asset--land',
#        'id': '599d10f2-c6aa-4af6-a1a4-63d70e355202'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/283ed562-d369-4f1a-9b5e-369220f46383/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': '4713bddb-5dd9-49a8-8fca-468a81f656cd',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd'}},
#    'attributes': {'drupal_internal__id': 29,
#     'drupal_internal__revision_id': 75,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': 'tomato bush located in bed N° 13',
#     'timestamp': '2019-07-11T22:31:57+00:00',
#     'status': 'done',
#     'created': '2019-07-11T22:31:57+00:00',
#     'changed': '2019-07-11T22:31:57+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': None,
#     'is_group_assignment': False,
#     'geometry': None,
#     'is_movement': True},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': '96dcf1ac-d144-43e7-add0-56876800b8f4'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/uid'}}},
#     'asset': {'data': [{'type': 'asset--plant',
#        'id': 'cb246c0a-679b-45b3-a9fb-613e6d77dc21'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/file'}}},
#     'image': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': '96dcf1ac-d144-43e7-add0-56876800b8f4'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/quantity'}}},
#     'group': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/group'}}},
#     'location': {'data': [{'type': 'asset--land',
#        'id': '31193de8-9d38-4298-aaa5-3f41c05d4285'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4713bddb-5dd9-49a8-8fca-468a81f656cd/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': '4474adab-37e1-48ba-8c29-ed9c3110481a',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a'}},
#    'attributes': {'drupal_internal__id': 31,
#     'drupal_internal__revision_id': 76,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': '2019 bed N° 13 tomato ACE 55 located in bed N° 13',
#     'timestamp': '2019-07-11T22:41:04+00:00',
#     'status': 'done',
#     'created': '2019-07-11T22:41:04+00:00',
#     'changed': '2019-07-11T22:41:04+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': None,
#     'is_group_assignment': False,
#     'geometry': None,
#     'is_movement': True},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': '96dcf1ac-d144-43e7-add0-56876800b8f4'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/uid'}}},
#     'asset': {'data': [{'type': 'asset--plant',
#        'id': '14d971ee-15ef-41a5-ba69-cc1900934d2e'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/file'}}},
#     'image': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': '96dcf1ac-d144-43e7-add0-56876800b8f4'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/quantity'}}},
#     'group': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/group'}}},
#     'location': {'data': [{'type': 'asset--land',
#        'id': '31193de8-9d38-4298-aaa5-3f41c05d4285'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/4474adab-37e1-48ba-8c29-ed9c3110481a/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': 'f9006eef-45b8-463e-a459-bc41ba91390c',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c'}},
#    'attributes': {'drupal_internal__id': 32,
#     'drupal_internal__revision_id': 77,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': 'tomato del benach / st pierre   located in bed N° 10',
#     'timestamp': '2019-07-11T22:54:14+00:00',
#     'status': 'done',
#     'created': '2019-07-11T22:54:14+00:00',
#     'changed': '2019-07-11T22:54:14+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': None,
#     'is_group_assignment': False,
#     'geometry': {'value': 'LINESTRING (-8.629593104124069 37.14151053720079, -8.62956628203392 37.14152122777034, -8.629292696714401 37.14101449311255, -8.629311472177505 37.14101021685629, -8.629590421915054 37.14151481342881)',
#      'geo_type': 'LineString',
#      'lat': 37.14126716027137,
#      'lon': -8.629441363274232,
#      'left': -8.62959310412407,
#      'top': 37.14152122777034,
#      'right': -8.629292696714401,
#      'bottom': 37.14101021685629,
#      'geohash': 'ey9g79k',
#      'latlon': '37.141267160271,-8.6294413632742'},
#     'is_movement': True},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': '96dcf1ac-d144-43e7-add0-56876800b8f4'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/uid'}}},
#     'asset': {'data': [{'type': 'asset--plant',
#        'id': 'fca011c4-1cdd-4fbf-9c17-bcbda65e105c'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/file'}}},
#     'image': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': '96dcf1ac-d144-43e7-add0-56876800b8f4'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/quantity'}}},
#     'group': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/group'}}},
#     'location': {'data': [{'type': 'asset--land',
#        'id': '4b2323c4-a8c6-4616-9e50-8c9e43c0c027'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f9006eef-45b8-463e-a459-bc41ba91390c/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': 'f4722dfc-a415-4e99-882d-172ca577087f',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f'}},
#    'attributes': {'drupal_internal__id': 34,
#     'drupal_internal__revision_id': 78,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': '7/17/2019 - 7:33:34 PM',
#     'timestamp': '2019-07-17T18:33:34+00:00',
#     'status': 'done',
#     'created': '2019-07-17T18:37:14+00:00',
#     'changed': '2019-07-17T18:37:14+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': {'value': 'Plants look sick; nitrogen deficiency?',
#      'format': 'default',
#      'processed': '<p>Plants look sick; nitrogen deficiency?</p>\n'},
#     'is_group_assignment': False,
#     'geometry': None,
#     'is_movement': False},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': '9d1dc5d2-cce1-4b52-8a94-007c1b772936'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/uid'}}},
#     'asset': {'data': [{'type': 'asset--plant',
#        'id': '3f9e843f-e256-4c94-8a40-0608c2a96064'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/file'}}},
#     'image': {'data': [{'type': 'file--file',
#        'id': '5d341ba5-d2e3-48e8-8898-940f8006cc1f',
#        'meta': {'alt': None, 'title': None, 'width': 4032, 'height': 3024}}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': '9d1dc5d2-cce1-4b52-8a94-007c1b772936'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/quantity'}}},
#     'group': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/group'}}},
#     'location': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/f4722dfc-a415-4e99-882d-172ca577087f/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': 'cf4cc044-579f-49b8-be46-64df494363e0',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0'}},
#    'attributes': {'drupal_internal__id': 35,
#     'drupal_internal__revision_id': 79,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': '7/18/2019 - 12:20:49 AM',
#     'timestamp': '2019-07-17T23:20:49+00:00',
#     'status': 'done',
#     'created': '2019-07-17T23:22:55+00:00',
#     'changed': '2019-09-05T16:53:39+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': None,
#     'is_group_assignment': False,
#     'geometry': {'value': 'LINESTRING (-8.629593104124069 37.14151053720079, -8.62956628203392 37.14152122777034, -8.629292696714401 37.14101449311255, -8.629311472177505 37.14101021685629, -8.629590421915054 37.14151481342881)',
#      'geo_type': 'LineString',
#      'lat': 37.14126716027137,
#      'lon': -8.629441363274232,
#      'left': -8.62959310412407,
#      'top': 37.14152122777034,
#      'right': -8.629292696714401,
#      'bottom': 37.14101021685629,
#      'geohash': 'ey9g79k',
#      'latlon': '37.141267160271,-8.6294413632742'},
#     'is_movement': False},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': '96dcf1ac-d144-43e7-add0-56876800b8f4'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/relationships/uid'}}},
#     'asset': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/relationships/file'}}},
#     'image': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/cf4cc044-579f-49b8-be46-64df494363e0/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
# ...
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8362ee73-e6a1-4531-94e7-86df469ff16b/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8362ee73-e6a1-4531-94e7-86df469ff16b/relationships/group'}}},
#     'location': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8362ee73-e6a1-4531-94e7-86df469ff16b/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8362ee73-e6a1-4531-94e7-86df469ff16b/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8362ee73-e6a1-4531-94e7-86df469ff16b/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8362ee73-e6a1-4531-94e7-86df469ff16b/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': '6b82565f-b489-48ee-98fa-c7d6d7198ab4',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4'}},
#    'attributes': {'drupal_internal__id': 186,
#     'drupal_internal__revision_id': 117,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': '12/3/2019 - 4:45:37 PM',
#     'timestamp': '2019-12-03T16:45:37+00:00',
#     'status': 'done',
#     'created': '2019-12-03T16:50:16+00:00',
#     'changed': '2019-12-03T16:50:16+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': None,
#     'is_group_assignment': False,
#     'geometry': {'value': 'POINT (-8.634107500000001 37.1561433)',
#      'geo_type': 'Point',
#      'lat': 37.1561433,
#      'lon': -8.6341075,
#      'left': -8.6341075,
#      'top': 37.1561433,
#      'right': -8.6341075,
#      'bottom': 37.1561433,
#      'geohash': 'ey9g7s0f4xnu4',
#      'latlon': '37.1561433,-8.6341075'},
#     'is_movement': False},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': 'f7268bcf-e373-4912-93bd-ad2c321dabd3'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/uid'}}},
#     'asset': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/file'}}},
#     'image': {'data': [{'type': 'file--file',
#        'id': '32929a0f-571e-4880-aa96-df772260e344',
#        'meta': {'alt': None, 'title': None, 'width': 3016, 'height': 4032}}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': 'f7268bcf-e373-4912-93bd-ad2c321dabd3'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/quantity'}}},
#     'group': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/group'}}},
#     'location': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/6b82565f-b489-48ee-98fa-c7d6d7198ab4/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': '8e58b96c-2e5c-4a97-a2d5-f33872f19cd2',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2'}},
#    'attributes': {'drupal_internal__id': 188,
#     'drupal_internal__revision_id': 118,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': '12/3/2019 - 5:11:15 PM',
#     'timestamp': '2019-12-03T17:11:15+00:00',
#     'status': 'done',
#     'created': '2019-12-04T15:18:25+00:00',
#     'changed': '2019-12-04T15:18:25+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': None,
#     'is_group_assignment': False,
#     'geometry': {'value': 'POINT (-8.632365099999999 37.1402626)',
#      'geo_type': 'Point',
#      'lat': 37.1402626,
#      'lon': -8.6323651,
#      'left': -8.6323651,
#      'top': 37.1402626,
#      'right': -8.6323651,
#      'bottom': 37.1402626,
#      'geohash': 'ey9g794jeqf01',
#      'latlon': '37.1402626,-8.6323651'},
#     'is_movement': False},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': 'f7268bcf-e373-4912-93bd-ad2c321dabd3'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/uid'}}},
#     'asset': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/file'}}},
#     'image': {'data': [{'type': 'file--file',
#        'id': '77f2fb34-f00f-4517-9874-5f4268635e23',
#        'meta': {'alt': None, 'title': None, 'width': 4032, 'height': 3016}}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': 'f7268bcf-e373-4912-93bd-ad2c321dabd3'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/quantity'}}},
#     'group': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/group'}}},
#     'location': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/8e58b96c-2e5c-4a97-a2d5-f33872f19cd2/relationships/equipment'}}}}},
#   {'type': 'log--observation',
#    'id': '9d33a41e-80dc-4564-9b6a-134656e5d3ee',
#    'links': {'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee'}},
#    'attributes': {'drupal_internal__id': 189,
#     'drupal_internal__revision_id': 119,
#     'langcode': 'en',
#     'revision_created': '2021-06-23T00:43:35+00:00',
#     'revision_log_message': 'Migrated from farmOS 1.x on 2021-06-22',
#     'name': '12/3/2019 - 5:18:54 PM',
#     'timestamp': '2019-12-03T17:18:54+00:00',
#     'status': 'done',
#     'created': '2019-12-04T15:18:26+00:00',
#     'changed': '2019-12-04T15:18:26+00:00',
#     'default_langcode': True,
#     'revision_translation_affected': True,
#     'data': None,
#     'flag': [],
#     'notes': None,
#     'is_group_assignment': False,
#     'geometry': {'value': 'POINT (-8.632279199999999 37.1404923)',
#      'geo_type': 'Point',
#      'lat': 37.1404923,
#      'lon': -8.6322792,
#      'left': -8.6322792,
#      'top': 37.1404923,
#      'right': -8.6322792,
#      'bottom': 37.1404923,
#      'geohash': 'ey9g794pj3d47',
#      'latlon': '37.1404923,-8.6322792'},
#     'is_movement': False},
#    'relationships': {'log_type': {'data': {'type': 'log_type--log_type',
#       'id': '8b62ced5-8900-4cfb-8f62-b29ed9d24819'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/log_type'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/log_type'}}},
#     'revision_user': {'data': {'type': 'user--user',
#       'id': '42c53d07-a394-4a24-9bfe-ec69f3196a28'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/revision_user'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/revision_user'}}},
#     'uid': {'data': {'type': 'user--user',
#       'id': 'f7268bcf-e373-4912-93bd-ad2c321dabd3'},
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/uid'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/uid'}}},
#     'asset': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/asset'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/asset'}}},
#     'category': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/category'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/category'}}},
#     'file': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/file'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/file'}}},
#     'image': {'data': [{'type': 'file--file',
#        'id': 'd6c38e03-fbfc-4cfc-9ec0-0feb604daab4',
#        'meta': {'alt': None, 'title': None, 'width': 3016, 'height': 4032}}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/image'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/image'}}},
#     'owner': {'data': [{'type': 'user--user',
#        'id': 'f7268bcf-e373-4912-93bd-ad2c321dabd3'}],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/owner'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/owner'}}},
#     'quantity': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/quantity'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/quantity'}}},
#     'group': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/group'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/group'}}},
#     'location': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/location'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/location'}}},
#     'equipment': {'data': [],
#      'links': {'related': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/equipment'},
#       'self': {'href': 'http://vdl.farmos.dev/api/log/observation/9d33a41e-80dc-4564-9b6a-134656e5d3ee/relationships/equipment'}}}}}],
#  'links': {'next': {'href': 'http://vdl.farmos.dev/api/log/observation?page%5Boffset%5D=50&page%5Blimit%5D=50'},
#   'self': {'href': 'http://vdl.farmos.dev/api/log/observation'}}}

# %%
len(observation['data'])
# Out:
# 50

# %% [markdown]
# ## Queries that don't work right yet
